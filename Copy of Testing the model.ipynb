# %%
# !gdown 17y1gkUhIV6rZJg1gMG-gzVMnH27fm4Ij

# !pip install pyunpack
# !pip install patool
from pyunpack import Archive
Archive("CLWD.rar").extractall("")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17y1gkUhIV6rZJg1gMG-gzVMnH27fm4Ij
# To: /content/CLWD.rar
# 100% 3.35G/3.35G [00:45<00:00, 72.9MB/s]
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyunpack
#   Downloading pyunpack-0.3-py2.py3-none-any.whl (4.1 kB)
# Collecting easyprocess (from pyunpack)
#   Downloading EasyProcess-1.1-py3-none-any.whl (8.7 kB)
# Collecting entrypoint2 (from pyunpack)
#   Downloading entrypoint2-1.1-py2.py3-none-any.whl (9.9 kB)
# Installing collected packages: entrypoint2, easyprocess, pyunpack
# Successfully installed easyprocess-1.1 entrypoint2-1.1 pyunpack-0.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patool
#   Downloading patool-1.12-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: patool
# Successfully installed patool-1.12

# %%
# !gdown 1LTQipgETr8DilHSiLEM9gOMxv86K7Uol
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LTQipgETr8DilHSiLEM9gOMxv86K7Uol
# To: /content/good-ishpls_epoch-11.pth
#  60% 399M/666M [00:04<00:02, 104MB/s] Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/response.py", line 444, in _error_catcher
#     yield
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/response.py", line 567, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/response.py", line 533, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "/usr/lib/python3.10/http/client.py", line 466, in read
#     s = self.fp.read(amt)
#   File "/usr/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.10/ssl.py", line 1274, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.10/ssl.py", line 1130, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/gdown/cli.py", line 151, in main
#     filename = download(
#   File "/usr/local/lib/python3.10/dist-packages/gdown/download.py", line 274, in download
#     for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#   File "/usr/local/lib/python3.10/dist-packages/requests/models.py", line 760, in generate
#     for chunk in self.raw.stream(chunk_size, decode_content=True):
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/response.py", line 628, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/response.py", line 566, in read
#     with self._error_catcher():
#   File "/usr/lib/python3.10/contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/response.py", line 480, in _error_catcher
#     self._connection.close()
#   File "/usr/lib/python3.10/http/client.py", line 961, in close
#     sock.close()   # close it manually... there may be other refs
#   File "/usr/lib/python3.10/socket.py", line 502, in close
#     self._real_close()
#   File "/usr/lib/python3.10/ssl.py", line 1333, in _real_close
#     super()._real_close()
# KeyboardInterrupt
#  62% 411M/666M [00:05<00:03, 80.6MB/s]
# ^C

# %%
# !gdown 1h6-Pa1LlHUenEeBxIx-HrmcbXM39OsJL
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1h6-Pa1LlHUenEeBxIx-HrmcbXM39OsJL
# To: /content/good-ishpls_epoch-8.pth
#  68% 450M/666M [00:07<00:02, 79.9MB/s]Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gdown/download.py", line 274, in download
#     for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#   File "/usr/local/lib/python3.10/dist-packages/requests/models.py", line 760, in generate
#     for chunk in self.raw.stream(chunk_size, decode_content=True):
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/response.py", line 628, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/response.py", line 567, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/response.py", line 533, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "/usr/lib/python3.10/http/client.py", line 466, in read
#     s = self.fp.read(amt)
#   File "/usr/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.10/ssl.py", line 1274, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.10/ssl.py", line 1130, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/gdown/cli.py", line 151, in main
#     filename = download(
#   File "/usr/local/lib/python3.10/dist-packages/gdown/download.py", line 292, in download
#     sess.close()
#   File "/usr/local/lib/python3.10/dist-packages/requests/sessions.py", line 737, in close
#     v.close()
#   File "/usr/local/lib/python3.10/dist-packages/requests/adapters.py", line 326, in close
#     self.poolmanager.clear()
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/poolmanager.py", line 223, in clear
#     self.pools.clear()
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/_collections.py", line 100, in clear
#     self.dispose_func(value)
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/poolmanager.py", line 174, in <lambda>
#     self.pools = RecentlyUsedContainer(num_pools, dispose_func=lambda p: p.close())
#   File "/usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py", line 495, in close
#     if conn:
# KeyboardInterrupt
#  69% 458M/666M [00:07<00:03, 59.0MB/s]
# ^C

# %%
# !gdown 1qAqErrr9yIjp-Trhd9Wnfo-oSB04a-YJ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qAqErrr9yIjp-Trhd9Wnfo-oSB04a-YJ
# To: /content/good-ishpls_epoch-5.pth
# 100% 666M/666M [00:04<00:00, 148MB/s]

# %%
# !gdown 15IVWcMH54a_Cjw6B9x3UOufZJCDAvFIP
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15IVWcMH54a_Cjw6B9x3UOufZJCDAvFIP
# To: /content/good-ishpls_epoch-4.pth
# 100% 666M/666M [00:08<00:00, 77.7MB/s]

# %%
# !gdown 1EW76_ls4kjriAn_pHyvqB5TiKi1WSkHO
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EW76_ls4kjriAn_pHyvqB5TiKi1WSkHO
# To: /content/good-ishpls_epoch-2.pth
# 100% 666M/666M [00:06<00:00, 97.4MB/s]

# %%
# !gdown 1tB2zjzxxpeV9YE5FQXprJuHDazitEQ6S
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tB2zjzxxpeV9YE5FQXprJuHDazitEQ6S
# To: /content/Take_two_epoch-5.pth
# 100% 15.1M/15.1M [00:00<00:00, 64.6MB/s]

# %%
# Take two
# !gdown 1tB2zjzxxpeV9YE5FQXprJuHDazitEQ6S

# !gdown 1NPY-YrLRPcOtGj3eclsoCpVXgXdGuAFC

# !gdown 1tlbLWvkTvSrl6ND-IdIOwonO4v7S-yeW

# !gdown 1caJInLFHCgj2ZBzJWMan5fQMWQYp8fGJ

# !gdown 1caJInLFHCgj2ZBzJWMan5fQMWQYp8fGJ

# !gdown 1XTclpXUnqfZdLFKUTxdxvDhhxBAWVYWm

# !gdown 1dsgtIo0v9xjoYK5c_6_dbz6VnmQC7fIm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tB2zjzxxpeV9YE5FQXprJuHDazitEQ6S
# To: /content/Take_two_epoch-5.pth
# 100% 15.1M/15.1M [00:00<00:00, 41.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NPY-YrLRPcOtGj3eclsoCpVXgXdGuAFC
# To: /content/Take_two_epoch-4.pth
# 100% 15.1M/15.1M [00:00<00:00, 105MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1tlbLWvkTvSrl6ND-IdIOwonO4v7S-yeW
# To: /content/Take_two_epoch-3.pth
# 100% 15.1M/15.1M [00:00<00:00, 158MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1caJInLFHCgj2ZBzJWMan5fQMWQYp8fGJ
# To: /content/Take_two_epoch-2.pth
# 100% 15.1M/15.1M [00:00<00:00, 121MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1caJInLFHCgj2ZBzJWMan5fQMWQYp8fGJ
# To: /content/Take_two_epoch-2.pth
# 100% 15.1M/15.1M [00:00<00:00, 256MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1XTclpXUnqfZdLFKUTxdxvDhhxBAWVYWm
# To: /content/Take_two_epoch-1.pth
# 100% 15.1M/15.1M [00:00<00:00, 66.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1dsgtIo0v9xjoYK5c_6_dbz6VnmQC7fIm
# To: /content/Take_two_epoch-0.pth
# 100% 15.1M/15.1M [00:00<00:00, 95.0MB/s]

# %%
# custom dataset - length 60 000, returns watermarked and watermark free image
class Coles(Dataset):
  def __init__(self, transform = None):
    # , watermark_free, watermarked, transform = None, target_transform = None
    #self.watermark_free = Image.open("CLWD/train/Watermark_image" + watermark_free)
    #self.img_dir = watermarked
     self.transform = transform
    # self.target_transform = target_transform
    #C:\Users\Cole\Desktop/CLWD/
  def __getitem__(self, idx):
      img_path = r"C:\Users\Cole\Desktop/CLWD/CLWD/train/Watermarked_image/" + str(idx + 1) + ".jpg"
      watermarked = Image.open(img_path).convert('RGB')
      img_path = r"C:\Users\Cole\Desktop/CLWD/CLWD/train/Watermark_free_image/" + str(idx + 1) + ".jpg"
      watermark_free = Image.open(img_path).convert('RGB')

      transform_one = T.ToTensor()

      img = transform_one(watermarked)
      label = transform_one(watermark_free)

      # sample = {
      #     'data':img.float(),
      #     'label':label.float(),
      # }

      # watermarked.cuda()
      # watermark_free.cuda()

      return img.float(), label.float()

  def __len__(self):
    #hardcoded for now
    return 60_000

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from torchvision.io import read_image

from PIL import Image

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import torchvision.transforms as T

# class Encoder(nn.Module):
#   def __init__(self):
#     super().__init__()
#     #takes in 64*64 (or as much as I reasonably can) by 3 channels
#     self.encoder = nn.Sequential(
#         nn.Conv2d(3, 64, 3, stride = 2, padding = 1),
#         nn.ReLU(),
#         nn.Conv2d(64, 128, 3, stride = 2, padding = 1),
#         nn.ReLU(),
#         nn.Conv2d(128, 256, 3, stride = 2, padding = 1),
#         nn.ReLU(),
#         nn.Conv2d(256, 512, 3, stride = 2, padding = 1),
#         # nn.ReLU(),
#         # nn.Conv2d(512, 1024, 7),

#     )
#         # this may not be perfect but this is how i think it is right now
#         # conv2d(in_channels, out_channels, kernel size, stride, padding)
#         # in channels is the number of channels that are input, for this case 3 because R, G, B
#         # out channels is number of output(width of the matrix?), will be batch size - number of images
#         # kernel size, area of sqare (or rectangle if tuple is provided) that is used to convolve pixel
#         # kernel size will probably just be 3, meaning thagt if x is the convoluted pixel then it would take from pixels like this:
#         # PPP
#         # PxP
#         # PPP
#         # stride is how many pixels it skips, should probably just be 1
#         # padding is how much it leaves off the edges, should be 1

#     self.decoder = nn.Sequential(
#         # nn.ConvTranspose2d(1024, 512, 7),
#         # nn.ReLU(),
#         nn.ConvTranspose2d(512, 256, 3, stride = 2, padding = 1, output_padding = 1),
#         nn.ReLU(),
#         nn.ConvTranspose2d(256, 128, 3, stride = 2, padding = 1, output_padding = 1),
#         nn.ReLU(),
#         nn.ConvTranspose2d(128, 64, 3, stride = 2, padding = 1, output_padding = 1),
#         nn.ReLU(),
#         nn.ConvTranspose2d(64, 3, 3, stride = 2, padding = 1, output_padding = 1),
#         nn.Sigmoid()

#     )

#   # output
#   def forward(self, x):
#     #print("began")
#     encoded = self.encoder(x)
#     #print(encoded)
#     decoded = self.decoder(encoded)
#     return decoded

# class Encoder(nn.Module):
#   def __init__(self):
#     super().__init__()
#     #takes in 64*64 (or as much as I reasonably can) by 3 channels
#     self.encoder = nn.Sequential(
#         nn.Conv2d(3, 64, 3, stride = 2, padding = 1),
#         nn.ReLU(),
#         nn.Conv2d(64, 128, 3, stride = 2, padding = 1),
#         nn.ReLU(),
#         nn.Conv2d(128, 256, 3, stride = 2, padding = 1),
#         nn.ReLU(),
#         nn.Conv2d(256, 512, 3, stride = 2, padding = 1),
#         nn.ReLU(),
#         nn.Conv2d(512, 1024, 7),

#     )
#         # this may not be perfect but this is how i think it is right now
#         # conv2d(in_channels, out_channels, kernel size, stride, padding)
#         # in channels is the number of channels that are input, for this case 3 because R, G, B
#         # out channels is number of output(width of the matrix?), will be batch size - number of images
#         # kernel size, area of sqare (or rectangle if tuple is provided) that is used to convolve pixel
#         # kernel size will probably just be 3, meaning thagt if x is the convoluted pixel then it would take from pixels like this:
#         # PPP
#         # PxP
#         # PPP
#         # stride is how many pixels it skips, should probably just be 1
#         # padding is how much it leaves off the edges, should be 1

#     self.decoder = nn.Sequential(
#         nn.ConvTranspose2d(1024, 512, 7),
#         nn.ReLU(),
#         nn.ConvTranspose2d(512, 256, 3, stride = 2, padding = 1, output_padding = 1),
#         nn.ReLU(),
#         nn.ConvTranspose2d(256, 128, 3, stride = 2, padding = 1, output_padding = 1),
#         nn.ReLU(),
#         nn.ConvTranspose2d(128, 64, 3, stride = 2, padding = 1, output_padding = 1),
#         nn.ReLU(),
#         nn.ConvTranspose2d(64, 3, 3, stride = 2, padding = 1, output_padding = 1),
#         nn.Sigmoid()

#     )

  # def forward(self, x):
  #   #print("began")
  #   encoded = self.encoder(x)
  #   #print(encoded)
  #   decoded = self.decoder(encoded)
  #   return decoded

class Encoder(nn.Module):
  def __init__(self):
    super().__init__()
    #takes in 64*64 (or as much as I reasonably can) by 3 channels
    self.encoder = nn.Sequential(
        nn.Conv2d(3, 16, 3, stride = 2, padding = 1),
        nn.ReLU(),
        nn.Conv2d(16, 32, 3, stride = 2, padding = 1),
        nn.ReLU(),
        nn.Conv2d(32, 64, 7),

    )
        # this may not be perfect but this is how i think it is right now
        # conv2d(in_channels, out_channels, kernel size, stride, padding)
        # in channels is the number of channels that are input, for this case 3 because R, G, B
        # out channels is number of output(width of the matrix?), will be batch size - number of images
        # kernel size, area of sqare (or rectangle if tuple is provided) that is used to convolve pixel
        # kernel size will probably just be 3, meaning thagt if x is the convoluted pixel then it would take from pixels like this:
        # PPP
        # PxP
        # PPP
        # stride is how many pixels it skips, should probably just be 1
        # padding is how much it leaves off the edges, should be 1

    self.decoder = nn.Sequential(
        nn.ConvTranspose2d(64, 32, 7),
        nn.ReLU(),
        nn.ConvTranspose2d(32, 16, 3, stride = 2, padding = 1, output_padding = 1),
        nn.ReLU(),
        nn.ConvTranspose2d(16, 3, 3, stride = 2, padding = 1, output_padding = 1),
        nn.Sigmoid()

    )
  # output
  def forward(self, x):
    #print("began")
    encoded = self.encoder(x)

    #print(encoded)
    decoded = self.decoder(encoded)
    return decoded


model = Encoder()

checkpoint = torch.load('Take_two_epoch-5.pth')
model.load_state_dict(checkpoint['model_state_dict'])



epoch = checkpoint['epoch']
print("epoch:", str(epoch))
loss = checkpoint['loss']
print("Loss:", str(loss))

def display(img_path):
  img = mpimg.imread(img_path)
  imgplot = plt.imshow(img)
  plt.show()
  return 0

model.eval()

im = Image.open(r"Downloads/images.jpg")
im = im.resize((256, 256))

im.show()

transform = T.Compose([
    T.PILToTensor()
])

img_tensor = transform(im)

#print("input: ===================================")
#print(img_tensor.shape)
#print(img_tensor)


img_tensor = img_tensor / 255
img_tensor = img_tensor.float()

#print(img_tensor)

output = model(img_tensor)

#print(output)

output = output# * 255

#print("output: ============================")
#print(output.shape)
#print(output)

transform = T.ToPILImage()

img = transform(output)

img.show()
# Out:
# epoch: 5
# Loss: tensor(0.0052, requires_grad=True)

# %%
# Display image and label.
Coles_Data = Coles("")
train_dataloader = DataLoader(Coles_Data, batch_size=16, shuffle=True)


train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0]#.squeeze()
label = train_labels[0]


pic1 = transform(img)
pic1.show()

label = train_features[0]#.squeeze()
label = train_labels[0]
pic2 = transform(label)
pic2.show()

#print(f"Label: {label}")
# Out:
# Feature batch shape: torch.Size([16, 3, 256, 256])
# Labels batch shape: torch.Size([16, 3, 256, 256])
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F7BD6063880>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F7BD5D48430>

# %%
#function to display image
def display(img_path):
  img = mpimg.imread(img_path)
  imgplot = plt.imshow(img)
  plt.show()
  return 0

display("CLWD/train/Watermarked_image/10.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f7105f836e8b> in <cell line: 8>()
#       6   return 0
#       7
# ----> 8 display("CLWD/train/Watermarked_image/10.jpg")
#
# <ipython-input-2-f7105f836e8b> in display(img_path)
#       1 #function to display image
#       2 def display(img_path):
# ----> 3   img = mpimg.imread(img_path)
#       4   imgplot = plt.imshow(img)
#       5   plt.show()
#
# NameError: name 'mpimg' is not defined
